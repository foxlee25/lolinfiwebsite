# %%
from lxml.html import parse 
from urllib2 import urlopen
import unicodedata
import json
import requests
import os
import urllib

api_key = ["e77f7ad6-ffb7-4064-b005-e4c26cb02f19",
           "2fa114db-d3c9-4ddd-9795-4c60fbc3372f",
           "94b0e3d6-8d26-41fc-86a4-6ea1e3f73782",
           "c516c49f-c9bb-466d-aaf7-a8f42b3a553c"]

api_recorder = 0

server_dict = {'KR': 'kr', 'NA': 'na', 'EU': 'euw'}

current_server = server_dict['NA']

current_version = '5.22.3'

api_url = "https://" + current_server + ".api.pvp.net/"

png_url = "http://ddragon.leagueoflegends.com/cdn/" + current_version + '/img/item/'
#ability_order = ['Passive', 'Q', 'W', 'E', 'R']
#ability_style = 'white-space: nowrap; font-size:140%; color: #9797fc; font-weight:bold; text-shadow: 0 2px black; padding-right:14px;'

# %%
def api_request(req_type, req_id = 0, game_range = None):
    global api_recorder
    global current_server
    api_param = {"api_key": api_key[api_recorder]}
    api_recorder += 1
    if api_recorder == 4:
        api_recorder = 0
    includetimeline = False
    if game_range == None:
        begin = 0
        end = 9
    else:
        begin = game_range[0]
        end = game_range[1]
        includetimeline = True
    if req_type == "summonerbyname":
        url = api_url + "/api/lol/" + current_server + "/v1.4/summoner/by-name/" + str(req_id)    
    elif req_type == "matchhistory":
        url = api_url + "/api/lol/" + current_server + "/v2.2/matchhistory/" + str(req_id)
        api_param.update({"rankedQueues": "RANKED_SOLO_5x5", "beginIndex": str(begin), "endIndex": str(end)})
    elif req_type == "match":
        url = api_url + "/api/lol/" + current_server + "/v2.2/match/" + str(req_id)
        api_param.update({"includeTimeline": includetimeline})
    elif req_type == "summonerrankedstats":
        url = api_url + "/api/lol/" + current_server + "/v1.3/stats/by-summoner/" + str(req_id) +"/ranked"
        api_param.update({"season": "SEASON2015"})
    elif req_type == "summonerleagueentry" or req_type == 'summonerleague':
        summoner_list = ''
        for s in req_id:
            summoner_list += (str(s) + ',')
        url = api_url + "/api/lol/" + current_server + "/v2.5/league/by-summoner/" + summoner_list
        if req_type == "summonerleagueentry":
             url += "/entry"
        api_param.update({"season": "SEASON2015"})
    elif req_type == "champions":
        url = api_url + "/api/lol/static-data/" + current_server + "/v1.2/champion"
    elif req_type == "champion":
        url = api_url + "/api/lol/static-data/" + current_server + "/v1.2/champion/" + str(req_id)
        api_param.update({"champData": "all"})
    elif req_type == "items":
        url = api_url + "/api/lol/static-data/" + current_server + "/v1.2/item"
    for t in range(5):
        try:
            temp_request = requests.get(url, params = api_param)
            return temp_request.json()
        except:
            time.sleep(0.9 + random.randint(0,1)/500)
            continue
    err_log.append([req_type, req_id, api_key, int(time.time())])
    return None

# %%
item_info_overall = api_request('items')

item_info_overall = item_info_overall['data']

# %%
item_info_overall
# Out:
# {u'1001': {u'description': u'<groupLimit>Limited to 1.</groupLimit><br><br><unique>UNIQUE Passive - Enhanced Movement:</unique> +25 Movement Speed',
#   u'group': u'BootsNormal',
#   u'id': 1001,
#   u'name': u'Boots of Speed',
#   u'plaintext': u'Slightly increases Movement Speed'},
#  u'1004': {u'description': u'<stats><mana>+25% Base Mana Regen </mana></stats>',
#   u'id': 1004,
#   u'name': u'Faerie Charm',
#   u'plaintext': u'Slightly increases Mana Regen'},
#  u'1006': {u'description': u'<stats>+50% Base Health Regen </stats>',
#   u'id': 1006,
#   u'name': u'Rejuvenation Bead',
#   u'plaintext': u'Slightly increases Health Regen'},
#  u'1011': {u'description': u'<stats>+380 Health</stats>',
#   u'id': 1011,
#   u'name': u"Giant's Belt",
#   u'plaintext': u'Greatly increases Health'},
#  u'1018': {u'description': u'<stats>+20% Critical Strike Chance</stats>',
#   u'id': 1018,
#   u'name': u'Cloak of Agility',
#   u'plaintext': u'Increases critical strike chance'},
#  u'1026': {u'description': u'<stats>+40 Ability Power</stats>',
#   u'id': 1026,
#   u'name': u'Blasting Wand',
#   u'plaintext': u'Moderately increases Ability Power'},
#  u'1027': {u'description': u'<stats><mana>+250 Mana</mana></stats>',
#   u'id': 1027,
#   u'name': u'Sapphire Crystal',
#   u'plaintext': u'Increases Mana'},
#  u'1028': {u'description': u'<stats>+150 Health</stats>',
#   u'id': 1028,
#   u'name': u'Ruby Crystal',
#   u'plaintext': u'Increases Health'},
#  u'1029': {u'description': u'<stats>+15 Armor</stats>',
#   u'id': 1029,
#   u'name': u'Cloth Armor',
#   u'plaintext': u'Slightly increases Armor'},
#  u'1031': {u'description': u'<stats>+40 Armor</stats>',
#   u'id': 1031,
#   u'name': u'Chain Vest',
#   u'plaintext': u'Greatly increases Armor'},
#  u'1033': {u'description': u'<stats>+25 Magic Resist</stats>',
#   u'id': 1033,
#   u'name': u'Null-Magic Mantle',
#   u'plaintext': u'Slightly increases Magic Resist'},
#  u'1036': {u'description': u'<stats>+10 Attack Damage</stats>',
#   u'id': 1036,
#   u'name': u'Long Sword',
#   u'plaintext': u'Slightly increases Attack Damage'},
#  u'1037': {u'description': u'<stats>+25 Attack Damage</stats>',
#   u'id': 1037,
#   u'name': u'Pickaxe',
#   u'plaintext': u'Moderately increases Attack Damage'},
#  u'1038': {u'description': u'<stats>+40 Attack Damage</stats>',
#   u'id': 1038,
#   u'name': u'B. F. Sword',
#   u'plaintext': u'Greatly increases Attack Damage'},
#  u'1039': {u'description': u'<stats><mana>+150% Mana Regeneration while in Jungle.  </mana></stats><br><br><unique>UNIQUE Passive - Tooth:</unique> Damaging a monster steals 20 Health over 5 seconds. Killing a Large Monster grants +15 bonus experience.',
#   u'id': 1039,
#   u'name': u"Hunter's Talisman",
#   u'plaintext': u'Provides damage against Monsters and Mana Regeneration in the Jungle'},
#  u'1041': {u'description': u'<stats>+8% Life Steal vs. Monsters</stats><br><br><unique>UNIQUE Passive - Nail:</unique> Basic attacks deal 20 bonus damage on hit vs. Monsters.  Killing a Large Monster grants +15 bonus experience.',
#   u'id': 1041,
#   u'name': u"Hunter's Machete",
#   u'plaintext': u'Provides damage and life steal versus Monsters'},
#  u'1042': {u'description': u'<stats>+12% Attack Speed</stats>',
#   u'id': 1042,
#   u'name': u'Dagger',
#   u'plaintext': u'Slightly increases Attack Speed'},
#  u'1043': {u'description': u'<stats>+25% Attack Speed</stats><br><br><unique>UNIQUE Passive:</unique> Basic attacks deal an additional 15 physical damage on hit.',
#   u'id': 1043,
#   u'name': u'Recurve Bow',
#   u'plaintext': u'Greatly increases Attack Speed'},
#  u'1051': {u'description': u'<stats>+10% Critical Strike Chance</stats>',
#   u'id': 1051,
#   u'name': u"Brawler's Gloves",
#   u'plaintext': u'Slightly increases Critical Strike Chance'},
#  u'1052': {u'description': u'<stats>+20 Ability Power</stats>',
#   u'id': 1052,
#   u'name': u'Amplifying Tome',
#   u'plaintext': u'Slightly increases Ability Power'},
#  u'1053': {u'description': u'<stats>+15 Attack Damage<br>+10% Life Steal</stats>',
#   u'id': 1053,
#   u'name': u'Vampiric Scepter',
#   u'plaintext': u'Basic attacks restore Health'},
#  u'1054': {u'description': u'<stats>+80 Health</stats><br><br><passive>Passive: </passive> Restores 6 Health every 5 seconds.<br><unique>UNIQUE Passive:</unique> Blocks 8 damage from single target attacks and spells from champions.',
#   u'id': 1054,
#   u'name': u"Doran's Shield",
#   u'plaintext': u'Good defensive starting item'},
#  u'1055': {u'description': u'<stats>+8 Attack Damage<br>+80 Health<br>+3% Life Steal</stats>',
#   u'id': 1055,
#   u'name': u"Doran's Blade",
#   u'plaintext': u'Good starting item for attackers'},
#  u'1056': {u'description': u'<stats>+60 Health<br>+15 Ability Power<br><mana>+50% Base Mana Regen  </mana></stats><br><br><mana><passive>Passive:</passive> Restores 4 Mana upon killing a unit.</mana>',
#   u'id': 1056,
#   u'name': u"Doran's Ring",
#   u'plaintext': u'Good starting item for casters'},
#  u'1057': {u'description': u'<stats>+40 Magic Resist</stats>',
#   u'id': 1057,
#   u'name': u'Negatron Cloak',
#   u'plaintext': u'Moderately increases Magic Resist'},
#  u'1058': {u'description': u'<stats>+60 Ability Power</stats>',
#   u'id': 1058,
#   u'name': u'Needlessly Large Rod',
#   u'plaintext': u'Greatly increases Ability Power'},
#  u'1062': {u'description': u'<stats>+16 Attack Damage<br>+15% Attack Speed </stats><br><br><unique>UNIQUE Passive - Prospector:</unique> +150 Health',
#   u'id': 1062,
#   u'name': u"Prospector's Blade",
#   u'plaintext': u'Good starting item for attackers'},
#  u'1063': {u'description': u'<stats>+35 Ability Power</stats><br><br><passive>Passive :</passive> <mana>+6 Mana Regen per 5 seconds</mana><br><unique>UNIQUE Passive - Prospector:</unique> +150 Health',
#   u'id': 1063,
#   u'name': u"Prospector's Ring",
#   u'plaintext': u'Good starting item for casters'},
#  u'1074': {u'description': u"<stats>+100 Health<br>+10 Health Regen per 5 seconds</stats><br><br><unique>UNIQUE Passive:</unique> Blocks 8 damage from champion basic attacks.<br><br><groupLimit>Limited to 2 Doran's items on Showdown</groupLimit>",
#   u'group': u'DoransShowdown',
#   u'id': 1074,
#   u'name': u"Doran's Shield (Showdown)",
#   u'plaintext': u'Good defensive starting item'},
#  u'1075': {u'description': u"<stats>+70 Health<br>+7 Attack Damage<br>+3% Life Steal</stats><br><br><groupLimit>Limited to 2 Doran's items on Showdown</groupLimit>",
#   u'group': u'DoransShowdown',
#   u'id': 1075,
#   u'name': u"Doran's Blade (Showdown)",
#   u'plaintext': u'Good starting item for attackers'},
#  u'1076': {u'description': u"<stats>+60 Health<br>+15 Ability Power<br>+3 Mana Regen per 5 seconds</stats><br><br><passive>Passive:</passive> Restores 4 Mana upon killing a unit.<br><br><groupLimit>Limited to 2 Doran's items on Showdown</groupLimit>",
#   u'group': u'DoransShowdown',
#   u'id': 1076,
#   u'name': u"Doran's Ring (Showdown)",
#   u'plaintext': u'Good starting item for casters'},
#  u'1082': {u'description': u'<stats>+15 Ability Power<br>+25% increased Healing from Potions<br><mana>+100 Mana</mana></stats><br><br><unique>UNIQUE Passive - Dread:</unique> Grants +3 Ability Power per Glory.  <br><unique>UNIQUE Passive - Do or Die:</unique> Grants 2 Glory for a champion kill or 1 Glory for an assist, up to 10 Glory total. Lose 4 Glory on death.',
#   u'id': 1082,
#   u'name': u'The Dark Seal',
#   u'plaintext': u'Provides Ability Power and Mana.  Increases in power as you kill enemies.'},
#  u'1083': {u'description': u'<stats>+5 Attack Damage<br>+3 Life on Hit</stats><br><br><unique>UNIQUE Passive:</unique> Killing a minion grants 1 additional gold. Killing 100 minions grants an additional 300 bonus gold immediately and disables this passive.',
#   u'id': 1083,
#   u'name': u'Cull',
#   u'plaintext': u'Provides damage and lifesteal on hit - Killing minions grant bonus gold'},
#  u'1300': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Furor bonus.<br><br><unique>UNIQUE Passive - Furor:</unique> Upon dealing damage with a single target spell or attack (on hit), grants +12% Movement Speed that decays over 2 seconds.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsFuror',
#   u'id': 1300,
#   u'name': u'Enchantment: Furor',
#   u'plaintext': u'Increases movement speed upon dealing damage with a single target spell or basic attack'},
#  u'1301': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Alacrity bonus. <br><br><unique>UNIQUE Passive - Alacrity:</unique> +20 Movement Speed<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsAlacrity',
#   u'id': 1301,
#   u'name': u'Enchantment: Alacrity',
#   u'plaintext': u'Permanently grants a bonus to base movement speed'},
#  u'1302': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Captain bonus.<br><br><unique>UNIQUE Passive - Captain:</unique> Grants +10% Movement Speed to nearby approaching allied champions.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsCaptain',
#   u'id': 1302,
#   u'name': u'Enchantment: Captain',
#   u'plaintext': u'Grants bonus movement speed to approaching allied champions and minions'},
#  u'1303': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Distortion bonus.<br><br><unique>UNIQUE Passive - Distortion:</unique> Teleport, Flash, and Ghost summoner spell cooldowns are reduced by 15% and are granted additional mobility: <br><br><font color='#FFDD00'>Ghost:</font> Grants 40% Movement Speed from 27%.<br><font color='#FFDD00'>Flash:</font> 20% Movement Speed bonus for 1 second after cast.<br><font color='#FFDD00'>Teleport:</font> 30% Movement Speed bonus for 3 seconds after use.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsDistortion',
#   u'id': 1303,
#   u'name': u'Enchantment: Distortion',
#   u'plaintext': u'Greatly lowers the summoner spell cooldown of Teleport, Flash, and Ghost'},
#  u'1304': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Homeguard bonus.<br><br><unique>UNIQUE Passive - Homeguard:</unique> Visiting the shop vastly increases Health and Mana Regeneration and grants 200% bonus Movement Speed that decays over 8 seconds. Bonus Movement Speed and regeneration are disabled for 6 seconds upon dealing or taking damage.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsHomeguard',
#   u'id': 1304,
#   u'name': u'Enchantment: Homeguard',
#   u'plaintext': u'Fully restores health, mana, and grants a massive speed boost while visiting the shop'},
#  u'1305': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Furor bonus.<br><br><unique>UNIQUE Passive - Furor:</unique> Upon dealing damage with a single target spell or attack (on hit), grants +12% Movement Speed that decays over 2 seconds.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsFuror',
#   u'id': 1305,
#   u'name': u'Enchantment: Furor',
#   u'plaintext': u'Increases movement speed upon dealing damage with a single target spell or basic attack'},
#  u'1306': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Alacrity bonus. <br><br><unique>UNIQUE Passive - Alacrity:</unique> +20 Movement Speed<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsAlacrity',
#   u'id': 1306,
#   u'name': u'Enchantment: Alacrity',
#   u'plaintext': u'Permanently grants a bonus to base movement speed'},
#  u'1307': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Captain bonus.<br><br><unique>UNIQUE Passive - Captain:</unique> Grants +10% Movement Speed to nearby approaching allied champions.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsCaptain',
#   u'id': 1307,
#   u'name': u'Enchantment: Captain',
#   u'plaintext': u'Grants bonus movement speed to approaching allied champions and minions'},
#  u'1308': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Distortion bonus.<br><br><unique>UNIQUE Passive - Distortion:</unique> Teleport, Flash, and Ghost summoner spell cooldowns are reduced by 15% and are granted additional mobility: <br><br><font color='#FFDD00'>Ghost:</font> Grants 40% Movement Speed from 27%.<br><font color='#FFDD00'>Flash:</font> 20% Movement Speed bonus for 1 second after cast.<br><font color='#FFDD00'>Teleport:</font> 30% Movement Speed bonus for 3 seconds after use.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsDistortion',
#   u'id': 1308,
#   u'name': u'Enchantment: Distortion',
#   u'plaintext': u'Greatly lowers the summoner spell cooldown of Teleport, Flash, and Ghost'},
#  u'1309': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Homeguard bonus.<br><br><unique>UNIQUE Passive - Homeguard:</unique> Visiting the shop vastly increases Health and Mana Regeneration and grants 200% bonus Movement Speed that decays over 8 seconds. Bonus Movement Speed and regeneration are disabled for 6 seconds upon dealing or taking damage.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsHomeguard',
#   u'id': 1309,
#   u'name': u'Enchantment: Homeguard',
#   u'plaintext': u'Fully restores health, mana, and grants a massive speed boost while visiting the shop'},
#  u'1310': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Furor bonus.<br><br><unique>UNIQUE Passive - Furor:</unique> Upon dealing damage with a single target spell or attack (on hit), grants +12% Movement Speed that decays over 2 seconds.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsFuror',
#   u'id': 1310,
#   u'name': u'Enchantment: Furor',
#   u'plaintext': u'Increases movement speed upon dealing damage with a single target spell or basic attack'},
#  u'1311': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Alacrity bonus. <br><br><unique>UNIQUE Passive - Alacrity:</unique> +20 Movement Speed<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsAlacrity',
#   u'id': 1311,
#   u'name': u'Enchantment: Alacrity',
#   u'plaintext': u'Permanently grants a bonus to base movement speed'},
#  u'1312': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Captain bonus.<br><br><unique>UNIQUE Passive - Captain:</unique> Grants +10% Movement Speed to nearby approaching allied champions.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsCaptain',
#   u'id': 1312,
#   u'name': u'Enchantment: Captain',
#   u'plaintext': u'Grants bonus movement speed to approaching allied champions and minions'},
#  u'1313': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Distortion bonus.<br><br><unique>UNIQUE Passive - Distortion:</unique> Teleport, Flash, and Ghost summoner spell cooldowns are reduced by 15% and are granted additional mobility: <br><br><font color='#FFDD00'>Ghost:</font> Grants 40% Movement Speed from 27%.<br><font color='#FFDD00'>Flash:</font> 20% Movement Speed bonus for 1 second after cast.<br><font color='#FFDD00'>Teleport:</font> 30% Movement Speed bonus for 3 seconds after use.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsDistortion',
#   u'id': 1313,
#   u'name': u'Enchantment: Distortion',
#   u'plaintext': u'Greatly lowers the summoner spell cooldown of Teleport, Flash, and Ghost'},
#  u'1314': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Homeguard bonus.<br><br><unique>UNIQUE Passive - Homeguard:</unique> Visiting the shop vastly increases Health and Mana Regeneration and grants 200% bonus Movement Speed that decays over 8 seconds. Bonus Movement Speed and regeneration are disabled for 6 seconds upon dealing or taking damage.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsHomeguard',
#   u'id': 1314,
#   u'name': u'Enchantment: Homeguard',
#   u'plaintext': u'Fully restores health, mana, and grants a massive speed boost while visiting the shop'},
#  u'1315': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Furor bonus.<br><br><unique>UNIQUE Passive - Furor:</unique> Upon dealing damage with a single target spell or attack (on hit), grants +12% Movement Speed that decays over 2 seconds.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsFuror',
#   u'id': 1315,
#   u'name': u'Enchantment: Furor',
#   u'plaintext': u'Increases movement speed upon dealing damage with a single target spell or basic attack'},
#  u'1316': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Alacrity bonus. <br><br><unique>UNIQUE Passive - Alacrity:</unique> +20 Movement Speed<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsAlacrity',
#   u'id': 1316,
#   u'name': u'Enchantment: Alacrity',
#   u'plaintext': u'Permanently grants a bonus to base movement speed'},
#  u'1317': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Captain bonus.<br><br><unique>UNIQUE Passive - Captain:</unique> Grants +10% Movement Speed to nearby approaching allied champions.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsCaptain',
#   u'id': 1317,
#   u'name': u'Enchantment: Captain',
#   u'plaintext': u'Grants bonus movement speed to approaching allied champions and minions'},
#  u'1318': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Distortion bonus.<br><br><unique>UNIQUE Passive - Distortion:</unique> Teleport, Flash, and Ghost summoner spell cooldowns are reduced by 15% and are granted additional mobility: <br><br><font color='#FFDD00'>Ghost:</font> Grants 40% Movement Speed from 27%.<br><font color='#FFDD00'>Flash:</font> 20% Movement Speed bonus for 1 second after cast.<br><font color='#FFDD00'>Teleport:</font> 30% Movement Speed bonus for 3 seconds after use.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsDistortion',
#   u'id': 1318,
#   u'name': u'Enchantment: Distortion',
#   u'plaintext': u'Greatly lowers the summoner spell cooldown of Teleport, Flash, and Ghost'},
#  u'1319': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Homeguard bonus.<br><br><unique>UNIQUE Passive - Homeguard:</unique> Visiting the shop vastly increases Health and Mana Regeneration and grants 200% bonus Movement Speed that decays over 8 seconds. Bonus Movement Speed and regeneration are disabled for 6 seconds upon dealing or taking damage.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsHomeguard',
#   u'id': 1319,
#   u'name': u'Enchantment: Homeguard',
#   u'plaintext': u'Fully restores health, mana, and grants a massive speed boost while visiting the shop'},
#  u'1320': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Furor bonus.<br><br><unique>UNIQUE Passive - Furor:</unique> Upon dealing damage with a single target spell or attack (on hit), grants +12% Movement Speed that decays over 2 seconds.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsFuror',
#   u'id': 1320,
#   u'name': u'Enchantment: Furor',
#   u'plaintext': u'Increases movement speed upon dealing damage with a single target spell or basic attack'},
#  u'1321': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Alacrity bonus. <br><br><unique>UNIQUE Passive - Alacrity:</unique> +20 Movement Speed<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsAlacrity',
#   u'id': 1321,
#   u'name': u'Enchantment: Alacrity',
#   u'plaintext': u'Permanently grants a bonus to base movement speed'},
#  u'1322': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Captain bonus.<br><br><unique>UNIQUE Passive - Captain:</unique> Grants +10% Movement Speed to nearby approaching allied champions.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsCaptain',
#   u'id': 1322,
#   u'name': u'Enchantment: Captain',
#   u'plaintext': u'Grants bonus movement speed to approaching allied champions and minions'},
#  u'1323': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Distortion bonus.<br><br><unique>UNIQUE Passive - Distortion:</unique> Teleport, Flash, and Ghost summoner spell cooldowns are reduced by 15% and are granted additional mobility: <br><br><font color='#FFDD00'>Ghost:</font> Grants 40% Movement Speed from 27%.<br><font color='#FFDD00'>Flash:</font> 20% Movement Speed bonus for 1 second after cast.<br><font color='#FFDD00'>Teleport:</font> 30% Movement Speed bonus for 3 seconds after use.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsDistortion',
#   u'id': 1323,
#   u'name': u'Enchantment: Distortion',
#   u'plaintext': u'Greatly lowers the summoner spell cooldown of Teleport, Flash, and Ghost'},
#  u'1324': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Homeguard bonus.<br><br><unique>UNIQUE Passive - Homeguard:</unique> Visiting the shop vastly increases Health and Mana Regeneration and grants 200% bonus Movement Speed that decays over 8 seconds. Bonus Movement Speed and regeneration are disabled for 6 seconds upon dealing or taking damage.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsHomeguard',
#   u'id': 1324,
#   u'name': u'Enchantment: Homeguard',
#   u'plaintext': u'Fully restores health, mana, and grants a massive speed boost while visiting the shop'},
#  u'1325': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Furor bonus.<br><br><unique>UNIQUE Passive - Furor:</unique> Upon dealing damage with a single target spell or attack (on hit), grants +12% Movement Speed that decays over 2 seconds.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsFuror',
#   u'id': 1325,
#   u'name': u'Enchantment: Furor',
#   u'plaintext': u'Increases movement speed upon dealing damage with a single target spell or basic attack'},
#  u'1326': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Alacrity bonus. <br><br><unique>UNIQUE Passive - Alacrity:</unique> +20 Movement Speed<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsAlacrity',
#   u'id': 1326,
#   u'name': u'Enchantment: Alacrity',
#   u'plaintext': u'Permanently grants a bonus to base movement speed'},
#  u'1327': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Captain bonus.<br><br><unique>UNIQUE Passive - Captain:</unique> Grants +10% Movement Speed to nearby approaching allied champions.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsCaptain',
#   u'id': 1327,
#   u'name': u'Enchantment: Captain',
#   u'plaintext': u'Grants bonus movement speed to approaching allied champions and minions'},
#  u'1328': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Distortion bonus.<br><br><unique>UNIQUE Passive - Distortion:</unique> Teleport, Flash, and Ghost summoner spell cooldowns are reduced by 15% and are granted additional mobility: <br><br><font color='#FFDD00'>Ghost:</font> Grants 40% Movement Speed from 27%.<br><font color='#FFDD00'>Flash:</font> 20% Movement Speed bonus for 1 second after cast.<br><font color='#FFDD00'>Teleport:</font> 30% Movement Speed bonus for 3 seconds after use.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsDistortion',
#   u'id': 1328,
#   u'name': u'Enchantment: Distortion',
#   u'plaintext': u'Greatly lowers the summoner spell cooldown of Teleport, Flash, and Ghost'},
#  u'1329': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Homeguard bonus.<br><br><unique>UNIQUE Passive - Homeguard:</unique> Visiting the shop vastly increases Health and Mana Regeneration and grants 200% bonus Movement Speed that decays over 8 seconds. Bonus Movement Speed and regeneration are disabled for 6 seconds upon dealing or taking damage.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsHomeguard',
#   u'id': 1329,
#   u'name': u'Enchantment: Homeguard',
#   u'plaintext': u'Fully restores health, mana, and grants a massive speed boost while visiting the shop'},
#  u'1330': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Furor bonus.<br><br><unique>UNIQUE Passive - Furor:</unique> Upon dealing damage with a single target spell or attack (on hit), grants +12% Movement Speed that decays over 2 seconds.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsFuror',
#   u'id': 1330,
#   u'name': u'Enchantment: Furor',
#   u'plaintext': u'Increases movement speed upon dealing damage with a single target spell or basic attack'},
#  u'1331': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Alacrity bonus. <br><br><unique>UNIQUE Passive - Alacrity:</unique> +20 Movement Speed<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsAlacrity',
#   u'id': 1331,
#   u'name': u'Enchantment: Alacrity',
#   u'plaintext': u'Permanently grants a bonus to base movement speed'},
#  u'1332': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Captain bonus.<br><br><unique>UNIQUE Passive - Captain:</unique> Grants +10% Movement Speed to nearby approaching allied champions.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsCaptain',
#   u'id': 1332,
#   u'name': u'Enchantment: Captain',
#   u'plaintext': u'Grants bonus movement speed to approaching allied champions and minions'},
#  u'1333': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Distortion bonus.<br><br><unique>UNIQUE Passive - Distortion:</unique> Teleport, Flash, and Ghost summoner spell cooldowns are reduced by 15% and are granted additional mobility: <br><br><font color='#FFDD00'>Ghost:</font> Grants 40% Movement Speed from 27%.<br><font color='#FFDD00'>Flash:</font> 20% Movement Speed bonus for 1 second after cast.<br><font color='#FFDD00'>Teleport:</font> 30% Movement Speed bonus for 3 seconds after use.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsDistortion',
#   u'id': 1333,
#   u'name': u'Enchantment: Distortion',
#   u'plaintext': u'Greatly lowers the summoner spell cooldown of Teleport, Flash, and Ghost'},
#  u'1334': {u'description': u"<groupLimit>Limited to 1 of each enchantment type.</groupLimit><br>Enchants boots to have Homeguard bonus.<br><br><unique>UNIQUE Passive - Homeguard:</unique> Visiting the shop vastly increases Health and Mana Regeneration and grants 200% bonus Movement Speed that decays over 8 seconds. Bonus Movement Speed and regeneration are disabled for 6 seconds upon dealing or taking damage.<br><br><rules>(Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'BootsHomeguard',
#   u'id': 1334,
#   u'name': u'Enchantment: Homeguard',
#   u'plaintext': u'Fully restores health, mana, and grants a massive speed boost while visiting the shop'},
#  u'1400': {u'description': u'<stats>+60 Attack Damage<br>+10% Cooldown Reduction</stats>',
#   u'group': u'JungleItems',
#   u'id': 1400,
#   u'name': u'Enchantment: Warrior',
#   u'plaintext': u'Grants Attack Damage and Cooldown Reduction'},
#  u'1401': {u'description': u'<stats>+400 Health<br>+15% Bonus Health</stats><br><br><unique>UNIQUE Passive - Immolate:</unique> Deals 15 (+0.6 per champion level) magic damage a second to nearby enemies. Deals 100% bonus damage to monsters. ',
#   u'group': u'JungleItems',
#   u'id': 1401,
#   u'name': u'Enchantment: Cinderhulk',
#   u'plaintext': u'Grants Health and Immolate Aura'},
#  u'1402': {u'description': u'<stats>+40 Ability Power<br><mana>+250 Mana</mana><br>+10% Cooldown Reduction</stats><br><br><unique>UNIQUE Passive - Spellblade:</unique> After using an ability, the next basic attack deals 100% Base Attack Damage (+30% of Ability Power) bonus magic damage on hit (1.5 second cooldown). When directly attacking a monster, the bonus damage is reapplied in an AoE around the target, and 8% of your missing Mana is restored.',
#   u'group': u'JungleItems',
#   u'id': 1402,
#   u'name': u'Enchantment: Runeglaive',
#   u'plaintext': u'Grants Ability Power, Mana and Spellcasts empower your attacks'},
#  u'1403': {u'description': u'<stats>+40% Attack Speed<br>+30 Magic Damage on Hit</stats><br><br><unique>UNIQUE Passive - Devouring Spirit:</unique> Takedowns on large monsters and Champions increase the magic damage of this item by +1. Takedowns on Rift Scuttlers increase the magic damage of this item by +2. Takedowns on epic monsters increase the magic damage of this item by +5. At 30 Stacks, your Devourer becomes Sated, granting extra on Hit effects.',
#   u'group': u'JungleItems',
#   u'id': 1403,
#   u'name': u'Enchantment: Devourer',
#   u'plaintext': u'Increases Attack Speed, and gives increasing power as you kill Jungle Monsters and Champions'},
#  u'1408': {u'description': u'<stats>+60 Attack Damage<br>+10% Cooldown Reduction</stats>',
#   u'group': u'JungleItems',
#   u'id': 1408,
#   u'name': u'Enchantment: Warrior',
#   u'plaintext': u'Grants Attack Damage and Cooldown Reduction'},
#  u'1409': {u'description': u'<stats>+400 Health<br>+15% Bonus Health</stats><br><br><unique>UNIQUE Passive - Immolate:</unique> Deals 15 (+0.6 per champion level) magic damage a second to nearby enemies. Deals 100% bonus damage to monsters. ',
#   u'group': u'JungleItems',
#   u'id': 1409,
#   u'name': u'Enchantment: Cinderhulk',
#   u'plaintext': u'Grants Health and Immolate Aura'},
#  u'1410': {u'description': u'<stats>+40 Ability Power<br><mana>+250 Mana</mana><br>+10% Cooldown Reduction</stats><br><br><unique>UNIQUE Passive - Spellblade:</unique> After using an ability, the next basic attack deals 100% Base Attack Damage (+30% of Ability Power) bonus magic damage on hit (1.5 second cooldown). When directly attacking a monster, the bonus damage is reapplied in an AoE around the target, and 8% of your missing Mana is restored.',
#   u'group': u'JungleItems',
#   u'id': 1410,
#   u'name': u'Enchantment: Runeglaive',
#   u'plaintext': u'Grants Ability Power, Mana and Spellcasts empower your attacks'},
#  u'1411': {u'description': u'<stats>+40% Attack Speed<br>+30 Magic Damage on Hit</stats><br><br><unique>UNIQUE Passive - Devouring Spirit:</unique> Takedowns on large monsters and Champions increase the magic damage of this item by +1. Takedowns on Rift Scuttlers increase the magic damage of this item by +2. Takedowns on epic monsters increase the magic damage of this item by +5. At 30 Stacks, your Devourer becomes Sated, granting extra on Hit effects.',
#   u'group': u'JungleItems',
#   u'id': 1411,
#   u'name': u'Enchantment: Devourer',
#   u'plaintext': u'Increases Attack Speed, and gives increasing power as you kill Jungle Monsters and Champions'},
#  u'1412': {u'description': u'<stats>+60 Attack Damage<br>+10% Cooldown Reduction</stats>',
#   u'group': u'JungleItems',
#   u'id': 1412,
#   u'name': u'Enchantment: Warrior',
#   u'plaintext': u'Grants Attack Damage and Cooldown Reduction'},
#  u'1413': {u'description': u'<stats>+400 Health<br>+15% Bonus Health</stats><br><br><unique>UNIQUE Passive - Immolate:</unique> Deals 15 (+0.6 per champion level) magic damage a second to nearby enemies. Deals 100% bonus damage to monsters. ',
#   u'group': u'JungleItems',
#   u'id': 1413,
#   u'name': u'Enchantment: Cinderhulk',
#   u'plaintext': u'Grants Health and Immolate Aura'},
#  u'1414': {u'description': u'<stats>+40 Ability Power<br><mana>+250 Mana</mana><br>+10% Cooldown Reduction</stats><br><br><unique>UNIQUE Passive - Spellblade:</unique> After using an ability, the next basic attack deals 100% Base Attack Damage (+30% of Ability Power) bonus magic damage on hit (1.5 second cooldown). When directly attacking a monster, the bonus damage is reapplied in an AoE around the target, and 8% of your missing Mana is restored.',
#   u'group': u'JungleItems',
#   u'id': 1414,
#   u'name': u'Enchantment: Runeglaive',
#   u'plaintext': u'Grants Ability Power, Mana and Spellcasts empower your attacks'},
#  u'1415': {u'description': u'<stats>+40% Attack Speed<br>+30 Magic Damage on Hit</stats><br><br><unique>UNIQUE Passive - Devouring Spirit:</unique> Takedowns on large monsters and Champions increase the magic damage of this item by +1. Takedowns on Rift Scuttlers increase the magic damage of this item by +2. Takedowns on epic monsters increase the magic damage of this item by +5. At 30 Stacks, your Devourer becomes Sated, granting extra on Hit effects.',
#   u'group': u'JungleItems',
#   u'id': 1415,
#   u'name': u'Enchantment: Devourer',
#   u'plaintext': u'Increases Attack Speed, and gives increasing power as you kill Jungle Monsters and Champions'},
#  u'2003': {u'description': u'<groupLimit>Limited to 5 at one time. Limited to one type of Healing Potion.</groupLimit><br><br><consumable>Click to Consume:</consumable> Restores 150 Health over 15 seconds.',
#   u'group': u'HealthPotion',
#   u'id': 2003,
#   u'name': u'Health Potion',
#   u'plaintext': u'Consume to restore Health over time'},
#  u'2009': {u'description': u'<consumable>Click to Consume:</consumable> Restores 80 Health and 50 Mana over 10 seconds.',
#   u'id': 2009,
#   u'name': u'Total Biscuit of Rejuvenation'},
#  u'2010': {u'description': u'<consumable>Click to Consume:</consumable> Restores 20 health and 10 mana immediately and then 150 Health over 15 seconds.',
#   u'group': u'HealthPotion',
#   u'id': 2010,
#   u'name': u'Total Biscuit of Rejuvenation'},
#  u'2015': {u'description': u"<stats>+15% Attack Speed</stats><br><br><passive>Passive:</passive> Moving and attacking will make an attack <a href='Energized'>Energized</a>.<br><br><unique>UNIQUE Passive - Energized Strike:</unique> Your Energized attacks deal 30 bonus magic damage on hit.",
#   u'id': 2015,
#   u'name': u'Kircheis Shard',
#   u'plaintext': u'Attack speed and a chargable magic hit'},
#  u'2031': {u'description': u'<groupLimit>Limited to one type of Healing Potion.</groupLimit><br><br><active>UNIQUE Active:</active> Consumes a charge to restore 100 Health over 10 seconds. Holds up to 2 charges and refills upon visiting the shop.',
#   u'group': u'FlaskGroup',
#   u'id': 2031,
#   u'name': u'Refillable Potion',
#   u'plaintext': u'Restores Health over time. Refills at shop.'},
#  u'2032': {u'description': u'<groupLimit>Limited to one type of Healing Potion.</groupLimit><br><br><active>UNIQUE Active:</active> Consumes a charge to restore 60 Health and 35 Mana over 8 seconds.  Holds up to 5 charges and refills upon visiting the shop.<br><br>Killing a Large Monster grants one charge.<br><br><rules>(Killing a Large Monster at full charges will automatically consume the newest charge.)</rules>',
#   u'group': u'FlaskGroup',
#   u'id': 2032,
#   u'name': u"Hunter's Potion",
#   u'plaintext': u'Restores health and mana over time - Refills at shop and has increased capacity'},
#  u'2033': {u'description': u"<groupLimit>Limited to one type of Healing Potion.</groupLimit><br><br><active>UNIQUE Active:</active> Consumes a charge to restore 150 Health and 50 Mana over 12 seconds and grants <font color='#FF8811'><u>Touch of Corruption</u></font> during that time. Holds up to 3 charges that refills upon visiting the shop.<br><br><font color='#FF8811'><u>Touch of Corruption:</u></font> Damaging spells and attacks burn enemy champions for <levelScale>15 - 30</levelScale> magic damage over 3 seconds.<rules> (Half Damage for Area of Effect or Damage over Time spells. Damage increases with champion level.)</rules><br><br><rules>(Corrupting Potion can be used even at full Health and Mana)</rules>",
#   u'group': u'FlaskGroup',
#   u'id': 2033,
#   u'name': u'Corrupting Potion',
#   u'plaintext': u'Restores health and mana over time and boosts combat power - Refills at Shop'},
#  u'2043': {u'description': u"<groupLimit>Can only carry 2 Vision Wards in inventory.</groupLimit><br><br><consumable>Click to Consume:</consumable> Places a visible ward that reveals the surrounding area and invisible units in the area until killed. Limit 1 <font color='#BBFFFF'>Vision Ward</font> on the map per player.<br><br><rules>(Revealing a ward in this manner grants a portion of the gold reward when that unit is killed.)</rules>",
#   u'group': u'PinkWards',
#   u'id': 2043,
#   u'name': u'Vision Ward',
#   u'plaintext': u'Use to temporarily provide vision and stealth detection in an area'},
#  u'2045': {u'description': u"<stats>+500 Health</stats><br><br><unique>UNIQUE Passive:</unique> Item Active cooldowns are reduced by 10%.<br><active>UNIQUE Active - Warding:</active> Consumes a charge to place a <font color='#BBFFFF'>Stealth Ward</font> that reveals the surrounding area for 150 seconds.  Holds up to 4 charges and refills when visiting the shop.<br><br><rules>(A player may only have 3 <font color='#BBFFFF'>Stealth Wards</font> on the map at one time. Unique Passives with the same name don't stack.)</rules>",
#   u'id': 2045,
#   u'name': u'Ruby Sightstone',
#   u'plaintext': u'Greatly increases Health and provides Stealth Wards over time'},
#  u'2047': {u'description': u'<consumable>Click to Consume:</consumable> Grants detection of nearby invisible units for up to 5 minutes or until death.',
#   u'id': 2047,
#   u'name': u"Oracle's Extract",
#   u'plaintext': u'Allows champion to see invisible units'},
#  u'2049': {u'description': u"<stats>+150 Health</stats><br><br><active>UNIQUE Active - Warding:</active> Consumes a charge to place a <font color='#BBFFFF'>Stealth Ward</font> that reveals the surrounding area for 150 seconds.  Holds up to 3 charges which refill upon visiting the shop. <br><br><rules>(A player may only have 3 <font color='#BBFFFF'>Stealth Wards</font> on the map at one time. Unique Passives with the same name don't stack.)</rules>",
#   u'id': 2049,
#   u'name': u'Sightstone',
#   u'plaintext': u'Increases Health and provides Stealth Wards over time'},
#  u'2050': {u'description': u'<consumable>Click to Consume:</consumable> Places an invisible ward that reveals the surrounding area for 60 seconds.',
#   u'id': 2050,
#   u'name': u"Explorer's Ward"},
#  u'2051': {u'description': u'<stats>+200 Health<br>+125% Base Health Regeneration </stats><br><br><unique>UNIQUE Passive:</unique> Enemy spellcasts reduce the cooldown of Battle Cry by 1 second.<br><active>UNIQUE Active - Battle Cry:</active> Gain 30% Movement Speed, 20 Armor, and 20 Magic Resist for 3 seconds. 25 second cooldown.',
#   u'id': 2051,
#   u'name': u"Guardian's Horn",
#   u'plaintext': u'Activate for Movement Speed and a defensive boost'},
#  u'2052': {u'description': u'This savory blend of free-range, grass-fed Avarosan game hens and organic, non-ZMO Freljordian herbs contains the essential nutrients necessary to keep your Poro purring with pleasure.<br><br><i>All proceeds will be donated towards fighting Noxian animal cruelty.</i>',
#   u'group': u'RelicBase',
#   u'id': 2052,
#   u'name': u'Poro-Snax'},
#  u'2053': {u'description': u'<stats>+40 Armor<br>+125% Base Health Regen </stats><br><br><unique>UNIQUE Passive - Point Runner:</unique> Builds up to +20% Movement Speed over 2 seconds while near turrets and fallen turrets.',
#   u'id': 2053,
#   u'name': u'Raptor Cloak',
#   u'plaintext': u'Enhances Movement Speed near turrets'},
#  u'2054': {u'description': u'All the flavor of regular Poro-Snax, without the calories! Keeps your Poro happy AND healthy.<br><br><consumable>Click to Consume:</consumable> Gives your Poros a delicious healthy treat.',
#   u'group': u'RelicBase',
#   u'id': 2054,
#   u'name': u'Diet Poro-Snax'},
#  u'2138': {u'description': u"<stats><levelLimit>Level 9 required to purchase.</levelLimit></stats><br><br><consumable>Click to Consume:</consumable> Grants +300 Health, 25% Tenacity, increased champion size, and <font color='#FF8811'><u>Path of Iron</u></font> for 3 minutes.<br><br><font color='#FF8811'><u>Path of Iron:</u></font> Moving leaves a path behind that boosts allied champion's Movement Speed by 15%.<br><br><rules>(Only one Elixir effect may be active at a time.)</rules>",
#   u'group': u'Flasks',
#   u'id': 2138,
#   u'name': u'Elixir of Iron',
#   u'plaintext': u'Temporarily increases defenses. Leaves a trail for allies to follow.'},
#  u'2139': {u'description': u"<stats><levelLimit>Level 9 required to purchase.</levelLimit></stats><br><br><consumable>Click to Consume:</consumable> Grants +50 Ability Power, 15 bonus Mana Regen per 5 seconds and <font color='#FF8811'><u>Sorcery</u></font> for 3 minutes. <br><br><font color='#FF8811'><u>Sorcery:</u></font> Damaging a champion or turret deals 25 bonus True Damage. This effect has a 5 second cooldown versus champions but no cooldown versus turrets.<br><br><rules>(Only one Elixir effect may be active at a time.)</rules><br>",
#   u'group': u'Flasks',
#   u'id': 2139,
#   u'name': u'Elixir of Sorcery',
#   u'plaintext': u'Temporarily grants Ability Power and Bonus Damage to champions and turrets.'},
#  u'2140': {u'description': u"<stats><levelLimit>Level 9 required to purchase.</levelLimit></stats><br><br><consumable>Click to Consume:</consumable> Grants +30 Attack Damage and <font color='#FF8811'><u>Bloodlust</u></font> for 3 minutes.<br><br><font color='#FF8811'><u>Bloodlust:</u></font> Dealing physical damage to champions heals for 15% of the damage dealt.<br><br><rules>(Only one Elixir effect may be active at a time.)</rules>",
#   u'group': u'Flasks',
#   u'id': 2140,
#   u'name': u'Elixir of Wrath',
#   u'plaintext': u'Temporarily grants Attack Damage and heals you when dealing physical damage.'},
#  u'2301': {u'description': u"<stats>+200 Health<br>+25 Ability Power<br>+2 Gold per 10 seconds<br><mana>+150% Base Mana Regen </mana></stats><br><br><unique>UNIQUE Passive - Tribute:</unique> Spells and basic attacks against champions or buildings deal 15 additional damage and grant 15 Gold. This can occur up to 3 times every 30 seconds. <br><active>UNIQUE Active - Warding:</active> Consumes a charge to place a <font color='#BBFFFF'>Stealth Ward</font> that reveals the surrounding area for 150 seconds. Holds up to 4 charges which refill upon visiting the shop. <br><br><groupLimit>Limited to 1 Gold Income item</groupLimit><br><br><rules>(A player may only have 3 <font color='#BBFFFF'>Stealth Wards</font> on the map at one time. Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'GoldBase',
#   u'id': 2301,
#   u'name': u'Eye of the Watchers',
#   u'plaintext': u'Provides Ability Power and Stealth Wards over time'},
#  u'2302': {u'description': u"<stats>+200 Health<br>+150% Base Health Regen <br><mana>+150% Base Mana Regen </mana></stats><br><br><unique>UNIQUE Passive - Favor:</unique> Being near a minion death without dealing the killing blow grants 6 Gold and 10 Health.<br><active>UNIQUE Active - Warding:</active> Consumes a charge to place a <font color='#BBFFFF'>Stealth Ward</font> that reveals the surrounding area for 150 seconds. Holds up to 4 charges which refill upon visiting the shop.<br><br><groupLimit>Limited to 1 Gold Income item</groupLimit><br><br><rules>(A player may only have 3 <font color='#BBFFFF'>Stealth Wards</font> on the map at one time. Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'GoldBase',
#   u'id': 2302,
#   u'name': u'Eye of the Oasis',
#   u'plaintext': u'Provides Regeneration and Stealth Wards over time'},
#  u'2303': {u'description': u"<stats>+500 Health<br>+100% Base Health Regen <br>+2 Gold per 10 seconds </stats><br><br><unique>UNIQUE Passive - Spoils of War:</unique> Melee basic attacks execute minions below 400 Health. Killing a minion heals the owner and the nearest allied champion for 50 Health and grants them kill Gold. These effects require a nearby allied champion. Recharges every 30 seconds. Max 4 charges.<br><active>UNIQUE Active - Warding:</active> Consumes a charge to place a <font color='#BBFFFF'>Stealth Ward</font> that reveals the surrounding area for 150 seconds. Holds up to 4 charges which refill upon visiting the shop.<br><br><groupLimit>Limited to 1 Gold Income item</groupLimit><br><br><rules>(A player may only have 3 <font color='#BBFFFF'>Stealth Wards</font> on the map at one time. Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'GoldBase',
#   u'id': 2303,
#   u'name': u'Eye of the Equinox',
#   u'plaintext': u'Provides Health and Stealth Wards over time'},
#  u'3001': {u'description': u'<stats>+70 Ability Power<br>+50 Magic Resist</stats><br><br><aura>UNIQUE Aura:</aura> Reduces the Magic Resist of nearby enemies by 20.',
#   u'id': 3001,
#   u'name': u'Abyssal Scepter',
#   u'plaintext': u'Reduces Magic Resist of nearby enemies'},
#  u'3003': {u'description': u"<stats>+80 Ability Power<br><mana>+250 Mana<br>+50% Base Mana Regen </mana></stats><br><br><mana><unique>UNIQUE Passive - Insight:</unique> Grants Ability Power equal to 3% of maximum Mana.<br><unique>UNIQUE Passive - Mana Charge:</unique> Grants +8 maximum Mana (max +750 Mana) for each spell cast and Mana expenditure (occurs up to 2 times every 8 seconds). Transforms into Seraph's Embrace at +750 Mana.</mana>",
#   u'id': 3003,
#   u'name': u"Archangel's Staff",
#   u'plaintext': u'Increases Ability Power based on maximum Mana'},
#  u'3004': {u'description': u'<stats>+25 Attack Damage<br><mana>+250 Mana<br>+25% Base Mana Regen </mana></stats><br><br><mana><unique>UNIQUE Passive - Awe:</unique> Grants bonus Attack Damage equal to 2% of maximum Mana.<br><unique>UNIQUE Passive - Mana Charge:</unique> Grants +4 maximum Mana (max +750 Mana) for each basic attack, spell cast, and Mana expenditure (occurs up to 2 times every 8 seconds).<br><br>Transforms into Muramana at +750 Mana.</mana>',
#   u'id': 3004,
#   u'name': u'Manamune',
#   u'plaintext': u'Increases Attack Damage based on maximum Mana'},
#  u'3006': {u'description': u'<stats> +30% Attack Speed</stats><br><br><unique>UNIQUE Passive - Enhanced Movement:</unique> +45 Movement Speed',
#   u'id': 3006,
#   u'name': u"Berserker's Greaves",
#   u'plaintext': u'Enhances Movement Speed and Attack Speed'},
#  u'3007': {u'description': u"<stats>+80 Ability Power<br><mana>+250 Mana<br>+50% Base Mana Regen </mana></stats><br><br><mana><unique>UNIQUE Passive - Insight:</unique> Grants Ability Power equal to 3% of maximum Mana.<br><unique>UNIQUE Passive - Mana Charge:</unique> Grants +10 maximum Mana (max +750 Mana) for each spell cast and Mana expenditure (occurs up to 2 times every 6 seconds). Transforms into Seraph's Embrace at +750 Mana.<br></mana>",
#   u'id': 3007,
#   u'name': u"Archangel's Staff (Crystal Scar)",
#   u'plaintext': u'Increases Ability Power based on maximum Mana'},
# ...
#   u'group': u'RelicBase',
#   u'id': 3348,
#   u'name': u'Hextech Sweeper',
#   u'plaintext': u'Activate to reveal a nearby area of the map'},
#  u'3361': {u'description': u"<groupLimit>Limited to 1 Trinket.</groupLimit><levelLimit> *Level 9+ required to upgrade.</levelLimit><stats></stats><br><br><unique>UNIQUE Active:</unique> Consume a charge to place an invisible ward that reveals the surrounding area for 180 seconds.  Stores a charge every 60 seconds, up to 2 total. Limit 3 <font color='#BBFFFF'>Stealth Wards</font> on the map per player.<br><br><rules>(Trinkets cannot be used in the first 30 seconds of a game. Selling a Trinket will disable Trinket use for 120 seconds).</rules>",
#   u'group': u'RelicBase',
#   u'id': 3361,
#   u'name': u'Greater Stealth Totem (Trinket)',
#   u'plaintext': u'Periodically place a Stealth Ward'},
#  u'3362': {u'description': u"<groupLimit>Limited to 1 Trinket.</groupLimit><levelLimit> *Level 9+ required to upgrade.</levelLimit><stats></stats><br><br><unique>UNIQUE Active:</unique> Places a visible ward that reveals the surrounding area and invisible units in the area until killed (120 second cooldown). Limit 1 <font color='#BBFFFF'>Vision Ward</font> on the map per player.<br><br><rules>(Trinkets cannot be used in the first 30 seconds of a game. Selling a Trinket will disable Trinket use for 120 seconds).</rules>",
#   u'group': u'RelicBase',
#   u'id': 3362,
#   u'name': u'Greater Vision Totem (Trinket)',
#   u'plaintext': u'Periodically place a Vision Ward'},
#  u'3363': {u'description': u"<levelLimit>* Level 9+ required to upgrade.</levelLimit><br><br>Alters the <font color='#FFFFFF'>Warding Totem</font> Trinket:<br><br><stats><font color='#00FF00'>+</font> Massively increased cast range (+650%)<br><font color='#00FF00'>+</font> Infinite duration and does not count towards ward limit<br><font color='#00FF00'>+</font> 60% reduced cooldown<br><font color='#FF0000'>-</font> <font color='#FF6600'>Ward is visible, fragile and untargetable by allies</font><br><font color='#FF0000'>-</font> <font color='#FF6600'>Cannot store charges</font></stats>",
#   u'group': u'RelicBase',
#   u'id': 3363,
#   u'name': u'Farsight Alteration',
#   u'plaintext': u'Grants increased range and reveals the targetted area'},
#  u'3364': {u'description': u"<levelLimit>* Level 9+ required to upgrade.</levelLimit><stats></stats><br><br>Alters the <font color='#FFFFFF'>Sweeping Lens</font> Trinket:<br><br><stats><font color='#00FF00'>+</font> Increased detection radius<br><font color='#00FF00'>+</font> Sweeping effect follows you for 10 seconds<br><font color='#FF0000'>-</font> <font color='#FF6600'>Cast range reduced to zero</font></stats>",
#   u'group': u'RelicBase',
#   u'id': 3364,
#   u'name': u'Oracle Alteration',
#   u'plaintext': u'Disables nearby invisible wards and trap for a duration'},
#  u'3401': {u'description': u'<stats>+450 Health<br>+100% Base Health Regen <br>+10% Cooldown Reduction<br>+2 Gold per 10 seconds </stats><br><br><unique>UNIQUE Passive - Spoils of War:</unique> Melee basic attacks execute minions below 400 Health. Killing a minion heals the owner and a nearby allied champion for 50 and grants them kill Gold. These effects require a nearby allied champion. Recharges every 30 seconds. Max 4 charges.<br><unique>UNIQUE Active:</unique> Grant a shield to an ally equal to 10% of your maximum Health for 4 seconds. After 4 seconds, the shield explodes to slow nearby enemies by 40% for 2 seconds (60 second cooldown).<br><br><groupLimit>Limited to 1 Gold Income item</groupLimit>',
#   u'group': u'GoldBase',
#   u'id': 3401,
#   u'name': u'Face of the Mountain',
#   u'plaintext': u'Shield an ally from damage based on your Health'},
#  u'3460': {u'description': u"<unique>Active:</unique> Use this trinket to teleport to one of the battle platforms. Can only be used from the summoning platform.<br><br><i><font color='#FDD017'>''It is at this magical precipice where a champion is dismantled, reforged, and empowered.''</font></i>",
#   u'group': u'RelicBase',
#   u'id': 3460,
#   u'name': u'Golden Transcendence'},
#  u'3504': {u'description': u'<stats>+40 Ability Power<br>+10% Cooldown Reduction<br><mana>+100% Base Mana Regen </mana></stats><br><br><unique>UNIQUE Passive:</unique> +8% Movement Speed<br><unique>UNIQUE Passive:</unique> Your heals and shields on another allied champion grant them 15% Attack Speed and 30 magic damage on-hit for 6 seconds.<br><br><rules>(This does not include regeneration effects or effects on yourself.)</rules>',
#   u'id': 3504,
#   u'name': u'Ardent Censer',
#   u'plaintext': u'Shield and heal effects on other units grant them Attack Speed and bonus damage briefly'},
#  u'3508': {u'description': u'<stats>+65 Attack Damage<br>+20% Critical Strike Chance</stats><br><br><unique>UNIQUE Passive:</unique> +10% Cooldown Reduction.<br><unique>UNIQUE Passive:</unique> Gain up to +20% additional Cooldown Reduction equal to your Critical Strike Chance from other sources.<br><unique>UNIQUE Passive:</unique> Critical strikes restore 3% of your maximum Mana pool.',
#   u'id': 3508,
#   u'name': u'Essence Reaver',
#   u'plaintext': u'Critical Strike provides Cooldown Reduction and Mana'},
#  u'3512': {u'description': u'<stats>+60 Armor<br>+60 Magic Resist<br>+125% Base Health Regen <br></stats><br><unique>UNIQUE Passive - Point Runner:</unique> Builds up to +20% Movement Speed over 2 seconds while near turrets and fallen turrets.<br><active>UNIQUE Active:</active> Spawns a Void Gate at target location for 150 seconds. Every 4 seconds the gate makes a Voidspawn that travels down the nearest lane and decays over time. Voidspawn explodes when attacking structures. Voidspawn ignore champions and void targets (150 second cooldown).<br><br>The first and every fourth Voidspawn gain 15% of maximum Health as damage.',
#   u'id': 3512,
#   u'name': u"Zz'Rot Portal",
#   u'plaintext': u'Makes a Voidspawn generating Void Gate to push a lane with.'},
#  u'3599': {u'description': u'<stats></stats><br><active>Active:</active> Offer to bind with an ally for the remainder of the game, becoming Oathsworn Allies. Oathsworn empowers you both while near one another.',
#   u'group': u'TheBlackSpear',
#   u'id': 3599,
#   u'name': u'The Black Spear',
#   u'plaintext': u"Kalista's spear that binds an Oathsworn Ally."},
#  u'3671': {u'description': u'<stats>+60 Attack Damage<br>+10% Cooldown Reduction</stats>',
#   u'id': 3671,
#   u'name': u'Enchantment: Warrior'},
#  u'3672': {u'description': u'<stats>+400 Health<br>+15% Bonus Health</stats><br><br><unique>UNIQUE Passive - Immolate:</unique> Deals 15 (+0.6 per champion level) magic damage a second to nearby enemies. Deals 100% bonus damage to monsters. ',
#   u'id': 3672,
#   u'name': u'Enchantment: Cinderhulk'},
#  u'3673': {u'description': u'<stats>+40 Ability Power<br><mana>+250 Mana</mana><br>+10% Cooldown Reduction</stats><br><br><unique>UNIQUE Passive - Spellblade:</unique> After using an ability, the next basic attack deals 100% Base Attack Damage (+30% of Ability Power) bonus magic damage on hit (1.5 second cooldown). When directly attacking a monster, the bonus damage is reapplied in an AoE around the target, and 8% of your missing Mana is restored.',
#   u'id': 3673,
#   u'name': u'Enchantment: Runeglaive'},
#  u'3674': {u'description': u'<stats>+40% Attack Speed<br>+30 Magic Damage on Hit</stats><br><br><unique>UNIQUE Passive - Devouring Spirit:</unique> Takedowns on large monsters and Champions increase the magic damage of this item by +1. Takedowns on Rift Scuttlers increase the magic damage of this item by +2. Takedowns on epic monsters increase the magic damage of this item by +5. At 30 Stacks, your Devourer becomes Sated, granting extra on Hit effects.',
#   u'id': 3674,
#   u'name': u'Enchantment: Devourer'},
#  u'3706': {u'description': u'<groupLimit>Limited to 1 Jungle item</groupLimit><br><br><stats>+10% Life Steal vs. Monsters<br>+150% Mana Regeneration while in Jungle</stats><br><br><unique>UNIQUE Passive - Chilling Smite:</unique> Smite can be cast on enemy champions, dealing reduced true damage and stealing 20% movement speed for 2 seconds. <br><unique>UNIQUE Passive - Tooth / Nail:</unique> Basic attacks deal 20 bonus damage vs. monsters. Damaging a monster steals 30 Health over 5 seconds. Killing a Large Monster grants +30 bonus experience.',
#   u'group': u'JungleItems',
#   u'id': 3706,
#   u'name': u"Stalker's Blade",
#   u'plaintext': u'Lets your Smite slow Champions'},
#  u'3711': {u'description': u"<groupLimit>Limited to 1 Jungle item</groupLimit><br><br><stats>+10% Life Steal vs. Monsters<br>+150% Mana Regeneration while in Jungle</stats><br><br><unique>UNIQUE Passive - Tooth / Nail:</unique> Basic attacks deal 20 bonus damage vs. monsters. Damaging a monster steals 30 Health over 5 seconds. Killing a Large Monster grants +30 bonus experience.<br><active>UNIQUE Active - Warding (Minor):</active> Consumes a charge to place a <font color='#BBFFFF'>Stealth Ward</font> that reveals the surrounding area for 150 seconds.  Holds up to 2 charges which refill upon visiting the shop. <br><br><rules>(A player may only have 3 <font color='#BBFFFF'>Stealth Wards</font> on the map at one time. Unique Passives with the same name don't stack.)</rules>",
#   u'group': u'JungleItems',
#   u'id': 3711,
#   u'name': u"Tracker's Knife",
#   u'plaintext': u'Makes your Smite give extra gold from the enemy jungle'},
#  u'3715': {u'description': u'<groupLimit>Limited to 1 Jungle item</groupLimit><br><br><stats>+10% Life Steal vs. Monsters<br>+150% Mana Regeneration while in Jungle</stats><br><br><passive>Passive - Challenging Smite:</passive> Smite can be cast on enemy champions, marking them for 4 seconds. While marked, basic attacks deal true damage over 3 seconds, you have vision of them, and their damage to you is reduced by 20%.<br><unique>UNIQUE Passive - Tooth / Nail:</unique> Basic attacks deal 20 bonus damage vs. monsters. Damaging a monster steals 30 Health over 5 seconds. Killing a Large Monster grants +30 bonus experience.',
#   u'group': u'JungleItems',
#   u'id': 3715,
#   u'name': u"Skirmisher's Sabre",
#   u'plaintext': u'Lets your Smite mark Champions, giving you combat power against them.'},
#  u'3742': {u'description': u"<stats>+600 Health<br>+50 Armor</stats><br><br><unique>UNIQUE Passive - Dreadnought:</unique> While moving, build stacks of Momentum, increasing movement speed by up to 60 at 100 stacks. Momentum quickly decays while under the effects of a stun, taunt, fear, silence, blind, polymorph, or immobilize effect, and slowly decays while slowed.<br><unique>UNIQUE Passive - Crushing Blow:</unique> Basic attacks discharge all Momentum, dealing 1 physical damage per 2 stacks. If 100 stacks are discharged, damage is doubled and the target is slowed by 75% decaying over 1 second (melee only).<br><br><flavorText>''There's only one way you'll get this armor from me...'' - forgotten namesake</flavorText>",
#   u'id': 3742,
#   u'name': u"Dead Man's Plate",
#   u'plaintext': u'Build momentum as you move around then smash into enemies.'},
#  u'3744': {u'description': u"<stats>+40 Ability Power<br>+25 Magic Resist<br><mana>+50% Base Mana Regen </mana></stats><br><br><mana><unique>UNIQUE Passive - Mana Font:</unique> Restores 2% of missing Mana every 5 seconds.</mana><br><unique>UNIQUE Passive:</unique> Gain 30% Movement Speed and 10 Mana Regen per 5 seconds while in the river.<br><i>(Unique Passives with the same name do not stack.)</i><br><br><i><font color='#FDD017'>''News travels fast along the Ionian riverside.''</font></i>",
#   u'id': 3744,
#   u'name': u'Staff of Flowing Water',
#   u'plaintext': u'Get a power boost when moving through the river.'},
#  u'3748': {u'description': u"<stats>+450 Health<br>+50 Attack Damage<br>+100% Base Health Regen </stats><br><br><unique>UNIQUE Passive - Cleave:</unique> Basic attacks deal 5 + 1% of your maximum health as bonus physical damage  to your target and 40 + 2.5% of your maximum health as physical damage  to other enemies in a cone on hit.<br><active>UNIQUE Active - Crescent:</active> Cleave damage to all targets is increased to 40 + 10% of your maximum health as bonus physical damage  in a larger cone for your next basic attack (20 second cooldown).<br><br><i>(Unique Passives with the same name don't stack.)</i>",
#   u'id': 3748,
#   u'name': u'Titanic Hydra',
#   u'plaintext': u"Deals area of effect damage based on owner's health"},
#  u'3751': {u'description': u'<stats>+300 Health  </stats><br><br><unique>UNIQUE Passive - Immolate:</unique> Deals 5 (+1 per champion level) magic damage per second to nearby enemies. Deals 50% bonus damage to minions and monsters.',
#   u'id': 3751,
#   u'name': u"Bami's Cinder",
#   u'plaintext': u'Grants Health and Immolate Aura'},
#  u'3800': {u'description': u'<stats>+500 Health<br><mana>+300 Mana</mana><br>+100% Base Health Regen </stats><br><br><unique>UNIQUE Active:</unique> Grants +60% Movement Speed to nearby allies when moving towards enemies or enemy turrets for 3 seconds. After 3 seconds, a shockwave is emitted, slowing nearby enemy champion Movement Speed by 80% for 1 second(s) (90 second cooldown).<br><br>This effect may be reactivated early to instantly release the shockwave.',
#   u'id': 3800,
#   u'name': u'Righteous Glory',
#   u'plaintext': u'Grants Health, Mana. Activate to speed towards enemies and slow them.'},
#  u'3801': {u'description': u'<stats>+200 Health<br>+50% Base Health Regen </stats>',
#   u'id': 3801,
#   u'name': u'Crystalline Bracer',
#   u'plaintext': u'Grants Health and Health Regen'},
#  u'3812': {u'description': u'<stats>+65 Attack Damage<br>+10% Cooldown Reduction</stats><br><br><unique>UNIQUE Passive:</unique> Dealing physical damage heals for 12% of the damage dealt. This is 33% as effective for Area of Effect damage.<br><unique>UNIQUE Passive:</unique> 12% of damage taken is dealt as a Bleed effect over 3 seconds instead.',
#   u'id': 3812,
#   u'name': u"Death's Dance",
#   u'plaintext': u'Trades incoming damage now for incoming damage later'},
#  u'3901': {u'description': u'Requires 500 Silver Serpents.<br><br><unique>UNIQUE Passive:</unique> Cannon Barrage fires at an increasing rate over time (additional 6 waves over the duration).',
#   u'group': u'GangplankRUpgrade01',
#   u'id': 3901,
#   u'name': u'Fire at Will',
#   u'plaintext': u'Cannon Barrage gains extra waves'},
#  u'3902': {u'description': u'Requires 500 Silver Serpents.<br><br><unique>UNIQUE Passive:</unique>  Cannon Barrage additionally fires a mega-cannonball at center of the Barrage, dealing 300% true damage and slowing them by 60% for 1.5 seconds. ',
#   u'group': u'GangplankRUpgrade02',
#   u'id': 3902,
#   u'name': u"Death's Daughter",
#   u'plaintext': u'Cannon Barrage fires a mega-cannonball'},
#  u'3903': {u'description': u'Requires 500 Silver Serpents.<br><br><unique>UNIQUE Passive:</unique> Allies in the Cannon Barrage gain 30% Movement Speed for 2 seconds.',
#   u'group': u'GangplankRUpgrade03',
#   u'id': 3903,
#   u'name': u'Raise Morale',
#   u'plaintext': u'Cannon Barrage hastes allies'},
#  u'3930': {u'description': u'<stats>+40% Attack Speed<br>+60 Magic Damage on Hit</stats><br><br><passive>Passive - Phantom Hit:</passive> Every other basic attack will trigger on Hit effects an additional time. Ranged champions trigger this every fourth attack.',
#   u'group': u'JungleItems',
#   u'id': 3930,
#   u'name': u'Enchantment: Sated Devourer'},
#  u'3931': {u'description': u'<stats>+40% Attack Speed<br>+60 Magic Damage on Hit</stats><br><br><passive>Passive - Phantom Hit:</passive> Every other basic attack will trigger on Hit effects an additional time. Ranged champions trigger this every fourth attack.',
#   u'group': u'JungleItems',
#   u'id': 3931,
#   u'name': u'Enchantment: Sated Devourer'},
#  u'3932': {u'description': u'<stats>+40% Attack Speed<br>+60 Magic Damage on Hit</stats><br><br><passive>Passive - Phantom Hit:</passive> Every other basic attack will trigger on Hit effects an additional time. Ranged champions trigger this every fourth attack.',
#   u'group': u'JungleItems',
#   u'id': 3932,
#   u'name': u'Enchantment: Sated Devourer'}}

# %%
for (iid, item) in item_info_overall.iteritems():
    urllib.urlretrieve(png_url + iid + ".png", iid + ".png")
    
with open('item_info.json', 'w+') as json_file:
    json.dump(item_info_overall, json_file, indent = 4)

# %%
api_request('champion', 117)
# Out:
# {u'allytips': [u'Glitterlance can be fired at odd angles depending on where your cursor is - Moving your cursor closer to Pix and Lulu will change your area of effect size considerably.',
#   u'Consider casting Help, Pix! on ranged attackers for the Pix boost and Wild Growth on Tanks or Fighters for the added initiation power.'],
#  u'blurb': u"Perhaps more than any other champion in the League, Lulu marches to the beat of her own drum. During her youth in Bandle City, she spent most of her time wandering alone in the forest or lost in a daydream. It wasn't that she was antisocial; the ...",
#  u'enemytips': [u"The shots from Lulu's faerie can be intercepted - hide behind your minions to avoid the additional Faerie attacks.",
#   u"Lulu excels when opponents heavily commit. Don't give her this chance! Use heavy harass tactics instead to force Lulu and her partner out of lane."],
#  u'id': 117,
#  u'image': {u'full': u'Lulu.png',
#   u'group': u'champion',
#   u'h': 48,
#   u'sprite': u'champion1.png',
#   u'w': 48,
#   u'x': 192,
#   u'y': 96},
#  u'info': {u'attack': 4, u'defense': 5, u'difficulty': 5, u'magic': 7},
#  u'key': u'Lulu',
#  u'lore': u"Perhaps more than any other champion in the League, Lulu marches to the beat of her own drum. During her youth in Bandle City, she spent most of her time wandering alone in the forest or lost in a daydream. It wasn't that she was antisocial; the day-to-day bustle of Bandle City just couldn't compete with the vibrant world of her imagination. She saw wonder in places most people overlooked. This was how she found Pix, a fae spirit, pretending to be stuck in a birdhouse. Lulu's imagination distinguished her to Pix and he seized the opportunity to lure her into his world. He brought her to the Glade, the enchanted home of the fae, which lay nestled in a clearing in the woods. There the rigid properties of the outside world - things like size and color - changed as frequently and whimsically as the direction of the wind. Lulu felt at home in the Glade and she lingered there with Pix, fascinated by this secret place.<br><br>She quickly lost track of time. Her life in the Glade was comfortable and natural. She and Pix played fae games together, the sorts of games that she had been told were ''make believe''... and she got exceedingly good at them. It caught her by surprise when she suddenly remembered that she had left a life behind in Bandle City. The Glade had a way of making everything outside seem distant and surreal. Lulu decided to revisit her former home, to share some of the lovely things she'd learned, but when she and Pix returned the world had changed. Time, she discovered, was another property that behaved differently in the Glade, and centuries had passed while she was away. Lulu sought to reconnect to the residents of the outside world but her attempts had unfortunate results. She led all the children off to play hide and seek, temporarily changing them into flowers and animals to spice up the game, but their parents didn't appreciate her efforts. When the yordles insisted that she leave their land, she turned to a vibrant magical place where those with unusual gifts were not just accepted but adored: the League of Legends.<br><br>''The best path between two points is upside-down, between, then inside-out and round again.''<br>-- Lulu",
#  u'name': u'Lulu',
#  u'partype': u'Mana',
#  u'passive': {u'description': u'Pix is a wild Faerie that accompanies Lulu. Pix will fire a barrage of magical energy at targets that Lulu attacks.',
#   u'image': {u'full': u'Lulu_PixFaerieCompanion.png',
#    u'group': u'passive',
#    u'h': 48,
#    u'sprite': u'passive1.png',
#    u'w': 48,
#    u'x': 192,
#    u'y': 96},
#   u'name': u'Pix, Faerie Companion',
#   u'sanitizedDescription': u'Pix is a wild Faerie that accompanies Lulu. Pix will fire a barrage of magical energy at targets that Lulu attacks.'},
#  u'skins': [{u'id': 117000, u'name': u'default', u'num': 0},
#   {u'id': 117001, u'name': u'Bittersweet Lulu', u'num': 1},
#   {u'id': 117002, u'name': u'Wicked Lulu', u'num': 2},
#   {u'id': 117003, u'name': u'Dragon Trainer Lulu', u'num': 3},
#   {u'id': 117004, u'name': u'Winter Wonder Lulu', u'num': 4},
#   {u'id': 117005, u'name': u'Pool Party Lulu', u'num': 5}],
#  u'spells': [{u'cooldown': [7.0, 7.0, 7.0, 7.0, 7.0],
#    u'cooldownBurn': u'7',
#    u'cost': [60, 65, 70, 75, 80],
#    u'costBurn': u'60/65/70/75/80',
#    u'costType': u'Mana',
#    u'description': u'Pix and Lulu each fire a bolt of magical energy that heavily slows all enemies it hits. An enemy can only be damaged by one bolt.',
#    u'effect': [None,
#     [80.0, 125.0, 170.0, 215.0, 260.0],
#     [80.0, 80.0, 80.0, 80.0, 80.0],
#     [1.0, 1.25, 1.5, 1.75, 2.0],
#     [0.5, 0.5, 0.5, 0.5, 0.5]],
#    u'effectBurn': [u'',
#     u'80/125/170/215/260',
#     u'80',
#     u'1/1.25/1.5/1.75/2',
#     u'0.5'],
#    u'image': {u'full': u'LuluQ.png',
#     u'group': u'spell',
#     u'h': 48,
#     u'sprite': u'spell6.png',
#     u'w': 48,
#     u'x': 192,
#     u'y': 48},
#    u'key': u'LuluQ',
#    u'leveltip': {u'effect': [u'{{ e1 }} -> {{ e1NL }}',
#      u'{{ e3 }} -> {{ e3NL }}',
#      u'{{ cost }} -> {{ costnNL }}'],
#     u'label': [u'Damage', u'Slow Duration', u'Mana Cost']},
#    u'maxrank': 5,
#    u'name': u'Glitterlance',
#    u'range': [925, 925, 925, 925, 925],
#    u'rangeBurn': u'925',
#    u'resource': u'{{ cost }} Mana',
#    u'sanitizedDescription': u'Pix and Lulu each fire a bolt of magical energy that heavily slows all enemies it hits. An enemy can only be damaged by one bolt.',
#    u'sanitizedTooltip': u'Lulu and Pix each fire a piercing bolt dealing {{ e1 }} (+{{ a1 }}) magic damage, slowing enemies hit by {{ e2 }}% for {{ e3 }} second(s). This slow decays over time. An enemy can only be damaged by one bolt.',
#    u'tooltip': u'Lulu and Pix each fire a piercing bolt dealing {{ e1 }} <span class="color99FF99">(+{{ a1 }})</span> magic damage, slowing enemies hit by {{ e2 }}% for {{ e3 }} second(s). This slow decays over time.<br><br>An enemy can only be damaged by one bolt.',
#    u'vars': [{u'coeff': [0.5], u'key': u'a1', u'link': u'spelldamage'}]},
#   {u'cooldown': [18.0, 16.5, 15.0, 13.5, 12.0],
#    u'cooldownBurn': u'18/16.5/15/13.5/12',
#    u'cost': [65, 65, 65, 65, 65],
#    u'costBurn': u'65',
#    u'costType': u'Mana',
#    u'description': u"If cast on an ally, grants them Movement Speed for a short time. If cast on an enemy, turns them into an adorable critter that can't attack or cast spells.",
#    u'effect': [None,
#     [30.0, 30.0, 30.0, 30.0, 30.0],
#     [20.0, 30.0, 40.0, 50.0, 60.0],
#     [1.25, 1.5, 1.75, 2.0, 2.25],
#     [60.0, 60.0, 60.0, 60.0, 60.0],
#     [3.0, 3.5, 4.0, 4.5, 5.0]],
#    u'effectBurn': [u'',
#     u'30',
#     u'20/30/40/50/60',
#     u'1.25/1.5/1.75/2/2.25',
#     u'60',
#     u'3/3.5/4/4.5/5'],
#    u'image': {u'full': u'LuluW.png',
#     u'group': u'spell',
#     u'h': 48,
#     u'sprite': u'spell6.png',
#     u'w': 48,
#     u'x': 240,
#     u'y': 48},
#    u'key': u'LuluW',
#    u'leveltip': {u'effect': [u'{{ e5 }} -> {{ e5NL }}',
#      u'{{ e3 }} -> {{ e3NL }}',
#      u'{{ cooldown }} -> {{ cooldownnNL }}'],
#     u'label': [u'Movement Speed Duration',
#      u'Polymorph Duration',
#      u'Cooldown']},
#    u'maxrank': 5,
#    u'name': u'Whimsy',
#    u'range': [650, 650, 650, 650, 650],
#    u'rangeBurn': u'650',
#    u'resource': u'{{ cost }} Mana',
#    u'sanitizedDescription': u"If cast on an ally, grants them Movement Speed for a short time. If cast on an enemy, turns them into an adorable critter that can't attack or cast spells.",
#    u'sanitizedTooltip': u'On Ally Cast: Target ally gains {{ e1 }} (+{{ a2 }})% Movement Speed for {{ e5 }} seconds. On Enemy Cast: Polymorphs an enemy champion for {{ e3 }} seconds, disabling their ability to attack or cast spells and reducing their base Movement Speed by {{ e4 }}.',
#    u'tooltip': u'<span class="colorCCFF99">On Ally Cast: </span>Target ally gains {{ e1 }} <span class="color99FF99">(+{{ a2 }})</span>% Movement Speed for {{ e5 }} seconds.<br><br><span class="colorFF9999">On Enemy Cast: </span>Polymorphs an enemy champion for {{ e3 }} seconds, disabling their ability to attack or cast spells and reducing their base Movement Speed by {{ e4 }}.',
#    u'vars': [{u'coeff': [0.1], u'key': u'a2', u'link': u'spelldamage'}]},
#   {u'cooldown': [10.0, 10.0, 10.0, 10.0, 10.0],
#    u'cooldownBurn': u'10',
#    u'cost': [60, 70, 80, 90, 100],
#    u'costBurn': u'60/70/80/90/100',
#    u'costType': u'Mana',
#    u'description': u'If cast on an ally, commands Pix to jump to an ally and shield them. He then follows them and aids their attacks. If cast on an enemy, commands Pix to jump to an enemy and damage them. He then follows them and grants you vision of that enemy.',
#    u'effect': [None,
#     [6.0, 6.0, 6.0, 6.0, 6.0],
#     [80.0, 120.0, 160.0, 200.0, 240.0],
#     [50.0, 50.0, 50.0, 50.0, 50.0],
#     [80.0, 110.0, 140.0, 170.0, 200.0],
#     [25.0, 25.0, 25.0, 25.0, 25.0],
#     [4.0, 4.0, 4.0, 4.0, 4.0]],
#    u'effectBurn': [u'',
#     u'6',
#     u'80/120/160/200/240',
#     u'50',
#     u'80/110/140/170/200',
#     u'25',
#     u'4'],
#    u'image': {u'full': u'LuluE.png',
#     u'group': u'spell',
#     u'h': 48,
#     u'sprite': u'spell6.png',
#     u'w': 48,
#     u'x': 288,
#     u'y': 48},
#    u'key': u'LuluE',
#    u'leveltip': {u'effect': [u'{{ e2 }} -> {{ e2NL }}',
#      u'{{ e4 }} -> {{ e4NL }}',
#      u'{{ cost }} -> {{ costnNL }}'],
#     u'label': [u'Shield Amount', u'Damage', u'Mana Cost']},
#    u'maxrank': 5,
#    u'name': u'Help, Pix!',
#    u'range': [650, 650, 650, 650, 650],
#    u'rangeBurn': u'650',
#    u'resource': u'{{ cost }} Mana',
#    u'sanitizedDescription': u'If cast on an ally, commands Pix to jump to an ally and shield them. He then follows them and aids their attacks. If cast on an enemy, commands Pix to jump to an enemy and damage them. He then follows them and grants you vision of that enemy.',
#    u'sanitizedTooltip': u"On Ally Cast: Commands Pix to jump to an ally and then follow and aid their attacks instead of Lulu's for {{ e1 }} seconds. If the ally is a champion, Pix shields them from {{ e2 }} (+{{ a1 }}) damage for {{ e1 }} seconds. On Enemy Cast: Pix deals {{ e4 }} (+{{ a2 }}) magic damage to target enemy unit. Pix then follows and grants vision of them for {{ e6 }} seconds.",
#    u'tooltip': u'<span class="colorCCFF99">On Ally Cast: </span>Commands Pix to jump to an ally and then follow and aid their attacks instead of Lulu\'s for {{ e1 }} seconds. If the ally is a champion, Pix shields them from {{ e2 }}<span class="color99FF99"> (+{{ a1 }})</span> damage for {{ e1 }} seconds.<br><br><span class="colorFF9999">On Enemy Cast: </span>Pix deals {{ e4 }}<span class="color99FF99"> (+{{ a2 }})</span> magic damage to target enemy unit. Pix then follows and grants vision of them for {{ e6 }} seconds.</span> ',
#    u'vars': [{u'coeff': [0.6], u'key': u'a1', u'link': u'spelldamage'},
#     {u'coeff': [0.4], u'key': u'a2', u'link': u'spelldamage'}]},
#   {u'cooldown': [110.0, 95.0, 80.0],
#    u'cooldownBurn': u'110/95/80',
#    u'cost': [100, 100, 100],
#    u'costBurn': u'100',
#    u'costType': u'Mana',
#    u'description': u'Lulu enlarges an ally, knocking nearby enemies into the air and granting the ally a large amount of bonus health. For the next few seconds, that ally gains an aura that slows nearby enemies.',
#    u'effect': [None,
#     [300.0, 450.0, 600.0],
#     [30.0, 45.0, 60.0],
#     [1.0, 1.0, 1.0],
#     [7.0, 7.0, 7.0],
#     [50.0, 50.0, 50.0]],
#    u'effectBurn': [u'', u'300/450/600', u'30/45/60', u'1', u'7', u'50'],
#    u'image': {u'full': u'LuluR.png',
#     u'group': u'spell',
#     u'h': 48,
#     u'sprite': u'spell6.png',
#     u'w': 48,
#     u'x': 336,
#     u'y': 48},
#    u'key': u'LuluR',
#    u'leveltip': {u'effect': [u'{{ e1 }} -> {{ e1NL }}',
#      u'{{ e2 }}% -> {{ e2NL }}%',
#      u'{{ cooldown }} -> {{ cooldownnNL }}'],
#     u'label': [u'bonus health', u'Slow Percent', u'Cooldown']},
#    u'maxrank': 3,
#    u'name': u'Wild Growth',
#    u'range': [900, 900, 900],
#    u'rangeBurn': u'900',
#    u'resource': u'{{ cost }} Mana',
#    u'sanitizedDescription': u'Lulu enlarges an ally, knocking nearby enemies into the air and granting the ally a large amount of bonus health. For the next few seconds, that ally gains an aura that slows nearby enemies.',
#    u'sanitizedTooltip': u'Lulu enlarges her ally, knocking nearby enemies into the air. For {{ e4 }} seconds, her ally gains {{ e1 }} (+{{ a1 }}) bonus health and slows nearby enemies by {{ e2 }}%.',
#    u'tooltip': u'Lulu enlarges her ally, knocking nearby enemies into the air. For {{ e4 }} seconds, her ally gains {{ e1 }}<span class="color99FF99"> (+{{ a1 }})</span> bonus health and slows nearby enemies by {{ e2 }}%.',
#    u'vars': [{u'coeff': [0.5], u'key': u'a1', u'link': u'spelldamage'}]}],
#  u'stats': {u'armor': 19.216,
#   u'armorperlevel': 3.7,
#   u'attackdamage': 46.368,
#   u'attackdamageperlevel': 2.6,
#   u'attackrange': 550.0,
#   u'attackspeedoffset': 0.0,
#   u'attackspeedperlevel': 2.25,
#   u'crit': 0.0,
#   u'critperlevel': 0.0,
#   u'hp': 552.76,
#   u'hpperlevel': 74.0,
#   u'hpregen': 6.005,
#   u'hpregenperlevel': 0.6,
#   u'movespeed': 325.0,
#   u'mp': 292.4,
#   u'mpperlevel': 55.0,
#   u'mpregen': 8.5,
#   u'mpregenperlevel': 0.6,
#   u'spellblock': 30.0,
#   u'spellblockperlevel': 0.0},
#  u'tags': [u'Support', u'Mage'],
#  u'title': u'the Fae Sorceress'}

# %%
urllib.urlretrieve("http://ddragon.leagueoflegends.com/cdn/img/champion/splash/Aatrox_0.jpg", "00000001.jpg")
# Out:
# ('00000001.jpg', <httplib.HTTPMessage instance at 0x1051a3a28>)

# %%
seen = set()
uniq = []
a = [1,1,2,3,4,5,4,3,4,7,8,0]
for x in a:
    if x not in seen:
        uniq.append(x)
        seen.add(x)
        
uniq

# %%
Counter(a)
